# %%
#short script to get graph of hong kong
import networkx
import osmnx as ox

G=ox.graph_from_address("Jordan,Kowloon",dist=500)

#metres

ox.plot_graph(G)

# you can export as shapefile if you want to explore to QGIS
# Out:
# (<Figure size 576x576 with 1 Axes>, <AxesSubplot:>)

# %%
ox.save_graph_shapefile(G, filepath=".")
# Out:
# /usr/local/lib/python3.9/site-packages/osmnx/io.py:108: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   gdf_nodes.to_file(filepath_nodes, driver="ESRI Shapefile", index=True, encoding=encoding)

# %%
# Out:
# '/Users/yeungarnold/jupyter/dissertation'
